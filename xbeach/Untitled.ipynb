# %%
# !sh autogen.sh
# Out:
# Preparing the xbeach build system...please wait
#
# Found GNU Autoconf version 2.69
# Found GNU Automake version 1.14.1
# Found GNU Libtool version 2.4.2
#
# Automatically preparing build ... done
#
# The xbeach build system is now prepared.  To build here, run:
#   ./configure
#   make
# If you want to run the executable from a specific directory:
#   ./configure --prefix=/path/to/executable/directory/withoutbin
#   make
#   make install

# %%
# !./configure --with-netcdf
# Out:
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking how to print strings... printf
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking for a sed that does not truncate output... /bin/sed
# checking for grep that handles long lines and -e... /bin/grep
# checking for egrep... /bin/grep -E
# checking for fgrep... /bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# ...

# %%
# !make
# Out:
# make  all-recursive
# make[1]: Entering directory '/workspace/volume/XBEACH/trunk'
# Making all in src
# make[2]: Entering directory '/workspace/volume/XBEACH/trunk/src'
# Making all in xbeachlibrary
# make[3]: Entering directory '/workspace/volume/XBEACH/trunk/src/xbeachlibrary'
# echo "Build_Revision = '`svnversion`'" > version.dat
# echo "Build_URL = '`svn info | grep -m 1 URL`'" >> version.dat
# echo "Build_Date = '`date`'" >> version.dat
# ../../scripts/generate.py
# INFO:__main__:parsing templates in /workspace/volume/XBEACH/trunk/scripts/../src/xbeachlibrary/templates
# INFO:__main__:converting chartoindex.f90 to chartoindex.inc
# INFO:__main__:converting genmpi_coll.f90 to genmpi_coll.inc
# INFO:__main__:converting genmpi_distr.f90 to genmpi_distr.inc
# INFO:__main__:converting get_var.f90 to get_var.inc
# INFO:__main__:converting get_var_shape.f90 to get_var_shape.inc
# INFO:__main__:converting getkey.f90 to getkey.inc
# ...

# %%
# !make install
# Out:
# Making install in src
# make[1]: Entering directory '/workspace/volume/XBEACH/trunk/src'
# Making install in xbeachlibrary
# make[2]: Entering directory '/workspace/volume/XBEACH/trunk/src/xbeachlibrary'
# make  install-am
# make[3]: Entering directory '/workspace/volume/XBEACH/trunk/src/xbeachlibrary'
# make[4]: Entering directory '/workspace/volume/XBEACH/trunk/src/xbeachlibrary'
#  /bin/mkdir -p '/usr/local/lib'
#  /bin/bash ../../libtool   --mode=install /usr/bin/install -c   libxbeach.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libxbeach.so.0.0.0 /usr/local/lib/libxbeach.so.0.0.0
# libtool: install: (cd /usr/local/lib && { ln -s -f libxbeach.so.0.0.0 libxbeach.so.0 || { rm -f libxbeach.so.0 && ln -s libxbeach.so.0.0.0 libxbeach.so.0; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libxbeach.so.0.0.0 libxbeach.so || { rm -f libxbeach.so && ln -s libxbeach.so.0.0.0 libxbeach.so; }; })
# ...

# %%
# !/usr/local/bin/xbeach
# Out:
#   **********************************************************
#                      Welcome to XBeach
#
#                version 1.22.5135
#                dateTue Apr 18 12:12:00 UTC 2017
#      URL:URL: https://svn.oss.deltares.nl/repos/xbeach/trunk/src/xbeachlibrary
#   **********************************************************
#
#   Simulation started: YYYYMMDD    hh:mm:ss     time zone (UTC)
#                       20170418  12:18:24     +0000
#
#     running in:/workspace/volume/XBEACH/trunk
#   General Input Module
#   Reading input parameters:
#    File 'params.txt' not found. Terminating simulation
#    File 'params.txt' not found. Terminating simulation
#  halt_program called by process           0
# #0  0x7F281579C407
# #1  0x7F281606E271
# #2  0x7F28160750BD
# #3  0x7F2816089DCD
# #4  0x7F28162B1EB4
# #5  0x400BEA in xbeach at xbeach.F90:18
# #6  0x7F2814A88B44
# STOP 1

# %%
# !make cleanall
# Out:
# make: *** No rule to make target 'cleanall'.  Stop.
